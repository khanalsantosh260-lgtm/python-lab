# %% [markdown]
# # Lab 4 - Instructions and problems
# **Exponential and logarithmic functions**<br>
# Software 2 - Mathematics Python Labs<br>
# School of ICT<br>
# Metropolia University of Applied Sciences
#
# ## Introduction
#
# In this lab you practise to make graphs of applications of exponential functions and logarithmic scales. The first problem is an example from Timo Salin's mathematics lecture notes related to the Newton's law of cooling.
#
# In the second problem you study a historical data of development of semiconductors used in modern microprcessors and computers. First your aim is to create a graph how the  number of tranistors in microchips has developed over the last 50 years. Then your task is to estimate how many transistors there will be at year 2030. For that, you use the graphs.
#
# Good luck!

# %% [markdown]
# ## Setup
#
# Add your name, change the student_id, and add date_returned.
#
# Import necessary libraries.
#
# **Note**: For problem 2 you need to have the file `transistors.dat` in the same working folder as your Notebooks are. Remember to download it.

# %%
name = "Santosh khanal" # Write your name between parenthesis
student_id = 2602056 # Change your student ID here
date_returned = "04/21" # Write the date returned between the parenthesis

import numpy as np
import matplotlib.pyplot as plt

# Test if data file for problem 2 is available
try:
    data = np.genfromtxt('transistors.dat', delimiter = '  ')
except OSError:
    print("transistors.dat not found. Please ensure the file is in the same directory as this script.")

# %% [markdown]
# ------------
#
# ## Problem 1
#
# ### Part a
#
# The temperature of a hot cup of coffee decreases according to the formula (See Timo Salin's mathematics lecture notes):
#
# $ T(t) = T_{env} + (T_0 - T_{env})\cdot e^{-kt} $
#
# where,
# - $T(t)$ is the temperature of the cup of coffee
# - $T_{env}$ is the temperature of the environment
# - $T_0$ is the initial temperature of the cup of coffee
# - $k$ is the time constant
# - $t$ is time
#
# Sketch a graph of $T(t)$, with the given  $T_{env}$, $T_0$, and $k$. Use the time range from 0.0 to 180.0 s. Select the time step properly to show a smooth curve.
#
# Annotate the graph (grid-lines, xlabel, ylabel, title).
#
# Notice, that each of you get individual random initial values based on your student_id. See the given code in the problems for more details.
#
# ### Part b
#
# When has the temperature fallen below 45 degrees? Find the answer graphically.
#
# Give the answer within 0.1 s accuracy.

# %%
# Initialize random number generator with student ID
rng = np.random.default_rng(student_id)
# Generate random time constant
k = rng.uniform(0.01, 0.05)
# Generate random initial temperature
T_0 = rng.uniform(80.0, 100.0)
T_env = 25.0 # Ambient temperature

print(f'Student ID: {student_id}')
print(f'k = {k:.3f} 1/s')
print(f'T_0 = {T_0:.1f} C')
print(f'T_env = {T_env:.1f} C')

# %%
# Your coimport numpy as np
import matplotlib.pyplot as plt

T_env = 20
T_0 = 90
k = 0.02

t = np.arange(0, 181, 1)

T = []

for time in t:
    temp = T_env + (T_0 - T_env) * np.exp(-k * time)
    T.append(temp)

plt.plot(t, T)
plt.axhline(45, linestyle='--')
plt.xlabel("Time (s)")
plt.ylabel("Temperature (°C)")
plt.title("Cooling of coffee")
plt.grid()
plt.show()

for i in range(len(T)):
    if T[i] < 45:
        print("Temperature goes below 45°C at time =", t[i], "seconds")
# Out:
# Temperature goes below 45°C at time = 52 seconds
# Temperature goes below 45°C at time = 53 seconds
# Temperature goes below 45°C at time = 54 seconds
# Temperature goes below 45°C at time = 55 seconds
# Temperature goes below 45°C at time = 56 seconds
# Temperature goes below 45°C at time = 57 seconds
# Temperature goes below 45°C at time = 58 seconds
# Temperature goes below 45°C at time = 59 seconds
# Temperature goes below 45°C at time = 60 seconds
# Temperature goes below 45°C at time = 61 seconds
# Temperature goes below 45°C at time = 62 seconds
# Temperature goes below 45°C at time = 63 seconds
# Temperature goes below 45°C at time = 64 seconds
# Temperature goes below 45°C at time = 65 seconds
# Temperature goes below 45°C at time = 66 seconds
# Temperature goes below 45°C at time = 67 seconds
# Temperature goes below 45°C at time = 68 seconds
# Temperature goes below 45°C at time = 69 seconds
# Temperature goes below 45°C at time = 70 seconds
# Temperature goes below 45°C at time = 71 seconds
# Temperature goes below 45°C at time = 72 seconds
# Temperature goes below 45°C at time = 73 seconds
# Temperature goes below 45°C at time = 74 seconds
# Temperature goes below 45°C at time = 75 seconds
# Temperature goes below 45°C at time = 76 seconds
# Temperature goes below 45°C at time = 77 seconds
# Temperature goes below 45°C at time = 78 seconds
# Temperature goes below 45°C at time = 79 seconds
# Temperature goes below 45°C at time = 80 seconds
# Temperature goes below 45°C at time = 81 seconds
# Temperature goes below 45°C at time = 82 seconds
# Temperature goes below 45°C at time = 83 seconds
# Temperature goes below 45°C at time = 84 seconds
# Temperature goes below 45°C at time = 85 seconds
# Temperature goes below 45°C at time = 86 seconds
# Temperature goes below 45°C at time = 87 seconds
# Temperature goes below 45°C at time = 88 seconds
# Temperature goes below 45°C at time = 89 seconds
# Temperature goes below 45°C at time = 90 seconds
# Temperature goes below 45°C at time = 91 seconds
# Temperature goes below 45°C at time = 92 seconds
# Temperature goes below 45°C at time = 93 seconds
# Temperature goes below 45°C at time = 94 seconds
# Temperature goes below 45°C at time = 95 seconds
# Temperature goes below 45°C at time = 96 seconds
# Temperature goes below 45°C at time = 97 seconds
# Temperature goes below 45°C at time = 98 seconds
# Temperature goes below 45°C at time = 99 seconds
# Temperature goes below 45°C at time = 100 seconds
# Temperature goes below 45°C at time = 101 seconds
# Temperature goes below 45°C at time = 102 seconds
# Temperature goes below 45°C at time = 103 seconds
# Temperature goes below 45°C at time = 104 seconds
# Temperature goes below 45°C at time = 105 seconds
# Temperature goes below 45°C at time = 106 seconds
# Temperature goes below 45°C at time = 107 seconds
# Temperature goes below 45°C at time = 108 seconds
# Temperature goes below 45°C at time = 109 seconds
# Temperature goes below 45°C at time = 110 seconds
# Temperature goes below 45°C at time = 111 seconds
# Temperature goes below 45°C at time = 112 seconds
# Temperature goes below 45°C at time = 113 seconds
# Temperature goes below 45°C at time = 114 seconds
# Temperature goes below 45°C at time = 115 seconds
# Temperature goes below 45°C at time = 116 seconds
# Temperature goes below 45°C at time = 117 seconds
# Temperature goes below 45°C at time = 118 seconds
# Temperature goes below 45°C at time = 119 seconds
# Temperature goes below 45°C at time = 120 seconds
# Temperature goes below 45°C at time = 121 seconds
# Temperature goes below 45°C at time = 122 seconds
# Temperature goes below 45°C at time = 123 seconds
# Temperature goes below 45°C at time = 124 seconds
# Temperature goes below 45°C at time = 125 seconds
# Temperature goes below 45°C at time = 126 seconds
# Temperature goes below 45°C at time = 127 seconds
# Temperature goes below 45°C at time = 128 seconds
# Temperature goes below 45°C at time = 129 seconds
# Temperature goes below 45°C at time = 130 seconds
# Temperature goes below 45°C at time = 131 seconds
# Temperature goes below 45°C at time = 132 seconds
# Temperature goes below 45°C at time = 133 seconds
# Temperature goes below 45°C at time = 134 seconds
# Temperature goes below 45°C at time = 135 seconds
# Temperature goes below 45°C at time = 136 seconds
# Temperature goes below 45°C at time = 137 seconds
# Temperature goes below 45°C at time = 138 seconds
# Temperature goes below 45°C at time = 139 seconds
# Temperature goes below 45°C at time = 140 seconds
# Temperature goes below 45°C at time = 141 seconds
# Temperature goes below 45°C at time = 142 seconds
# Temperature goes below 45°C at time = 143 seconds
# Temperature goes below 45°C at time = 144 seconds
# Temperature goes below 45°C at time = 145 seconds
# Temperature goes below 45°C at time = 146 seconds
# Temperature goes below 45°C at time = 147 seconds
# Temperature goes below 45°C at time = 148 seconds
# Temperature goes below 45°C at time = 149 seconds
# Temperature goes below 45°C at time = 150 seconds
# Temperature goes below 45°C at time = 151 seconds
# Temperature goes below 45°C at time = 152 seconds
# Temperature goes below 45°C at time = 153 seconds
# Temperature goes below 45°C at time = 154 seconds
# Temperature goes below 45°C at time = 155 seconds
# Temperature goes below 45°C at time = 156 seconds
# Temperature goes below 45°C at time = 157 seconds
# Temperature goes below 45°C at time = 158 seconds
# Temperature goes below 45°C at time = 159 seconds
# Temperature goes below 45°C at time = 160 seconds
# Temperature goes below 45°C at time = 161 seconds
# Temperature goes below 45°C at time = 162 seconds
# Temperature goes below 45°C at time = 163 seconds
# Temperature goes below 45°C at time = 164 seconds
# Temperature goes below 45°C at time = 165 seconds
# Temperature goes below 45°C at time = 166 seconds
# Temperature goes below 45°C at time = 167 seconds
# Temperature goes below 45°C at time = 168 seconds
# Temperature goes below 45°C at time = 169 seconds
# Temperature goes below 45°C at time = 170 seconds
# Temperature goes below 45°C at time = 171 seconds
# Temperature goes below 45°C at time = 172 seconds
# Temperature goes below 45°C at time = 173 seconds
# Temperature goes below 45°C at time = 174 seconds
# Temperature goes below 45°C at time = 175 seconds
# Temperature goes below 45°C at time = 176 seconds
# Temperature goes below 45°C at time = 177 seconds
# Temperature goes below 45°C at time = 178 seconds
# Temperature goes below 45°C at time = 179 seconds
# Temperature goes below 45°C at time = 180 seconds

# %% [markdown]
# ------
# ## Problem 2
#
# In 1965, **[Gordon Moore](https://en.wikipedia.org/wiki/Gordon_Moore)** was asked by Electronics Magazine to predict what might happen in the semiconductor components over the next ten years. Moore observed that the numbers of components (transistors, etc.) in a dense integrated circuit had doubled approximately every year and speculated it would continue to do so for at least the next ten years. This forecast rate has been revised since then but the basic principle has continued over 50 years.
#
# Now it is your turn to make predictions. The cleaned data in file `transistors.dat` is downloaded from **[What is Moore's Law? - Our World in Data](https://ourworldindata.org/moores-law)**. The data can be read in to Notebook with the following code:
# ```python
# # Notice, delimiter has two spaces!
# data = np.genfromtxt('transistors.dat', delimiter = '  ')
# year = data[:, 0]
# transistors = data[:, 1]
# ```
#
# and then plotted in linear scale using the code:
# ```Python
# # Scatter plot in linear scale
# plt.figure(figsize=(6,4))
# plt.scatter(year, transistors)
# plt.xlabel('Year')
# plt.ylabel('Number of transistors')
# plt.grid()
# ```
#
# Your task is to create a second graph of the data using semilogy scale, e.g. `plt.semilogy(year, transistors, 'o')`. The last 'o' changes the graph from line graph to scatter plot. Decorate also this graph.
#
# Find by [trial and error](https://en.wikipedia.org/wiki/Trial_and_error) the exponential relationship between the transistors and years, e.g. $y(x) = be^{k(x - 1970)}$, where $x$ is the year, $k$ is the growth factor, $b$ is the offset (number of transistors at 1970), and $y$ is the estimate of the number of the transistors. Draw this estimate line in the same graph with the data, e.g. use `plt.semilogy(x, y)`. Use $x \in [1970, 2030]$. Change the xlimits and ylimits to make the graphics more readable.
#
# Find the value of $y(2030)$. This is your prediction of the number of transistors in ICs at year 2030. **What is your prediction?** Give your estimation in scientific format with *three significant digits*  (=two decimals). For example, the following code:
#
# ```python
# N = 12345678
# print(f'N = {N:.2e}')
# ```
# prints out:
#
# `N = 1.23e+07`

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt('transistors.dat')

year = data[:, 0]
transistors = data[:, 1]

plt.scatter(year, transistors)
plt.xlabel("Year")
plt.ylabel("Number of transistors")
plt.grid()
plt.show()

plt.semilogy(year, transistors, 'o')

x_shift = year - 1970
y_log = []

for i in range(len(transistors)):
    y_log.append(np.log(transistors[i]))

coeff = np.polyfit(x_shift, y_log, 1)

k = coeff[0]
b = np.exp(coeff[1])

x = np.arange(1970, 2031, 1)

y = []

for i in range(len(x)):
    value = b * np.exp(k * (x[i] - 1970))
    y.append(value)

plt.semilogy(year, transistors, 'o')
plt.semilogy(x, y)
plt.xlabel("Year")
plt.ylabel("Number of transistors")
plt.grid()
plt.show()

y_2030 = b * np.exp(k * (2030 - 1970))

print("b =", b)
print("k =", k)
print("Prediction for 2030 =", y_2030)
# Out:
# b = 0.7105530779068571
# k = 0.3474443777715201
# Prediction for 2030 = 803872342.910352

# %% [markdown]
# ------
# ## Problem 3 (extra)
#
# This is an extra problem. Solve it, if you want practise more. It is not mandatory.
#
# ### Part a
#
# The voltage of a capacitor decays exponentially (See Software 1, Mathematics Lectures Period 1.pdf, page 27):
#
# $ y(t) = \begin{cases} V_0,\; t<t_0\;\text{ms} \\ V_0 \cdot e^{-(t - t_0)/RC}, \; t \geq t_0\;\text{ms} \end{cases}$
#
# Sketch the graph of the voltage of a capacitor in time-range from 0.0 ms to 10.0 ms (included) using timestep of 0.01 ms (Note: 1.0 ms = $1.0 \times 10^{3}$ s = 0.001 s). Use the following values in calculations:
# - $V_0 = 5.0$ V
# - $R = 1.2 \times 10^3 \;\Omega$
# - $C = 1.0 \times 10^{-6}$ F
# - $t_0 = 2.0 \times 10^{-3}$ s
#
# Annotate the graph (xlabel, ylabel, title, and grid-lines).

# %%
# Initial values
V0 = 5.0
R = 1.2e3
C = 1.0e-6
t0 = 2.0e-3

# Your code comes here

# %% [markdown]
# ### Part b
#
# Read from the graph when the voltage is dropped below 1.5 V. Give the answer within 0.1 ms accuracy. Create another graph, if needed, for more detailed analysis.

# %%
# Your code comes here
